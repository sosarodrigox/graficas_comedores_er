# %% [markdown]
# # TABLA: Beneficiarios - Inversión (Dic23-Jun24)

# %% [markdown]
# ### 1) Creo cada Dataframe por programa:

# %%
import pandas as pd

# Datos para cada programa
data_comedores = {
    'Mes': ['dic-23', 'ene-24', 'feb-24', 'mar-24', 'abr-24', 'may-24', 'jun-24'],
    'Beneficiarios': [108277, 14422, 14372, 108005, 108074, 109001, 111017],
    'Total ($)': [324826045.00, 129760000.00, 86968300.00, 1079547258.00, 1085019731.00, 1124986151.00, 1252674878.00]
}

data_cuidado = {
    'Mes': ['dic-23', 'ene-24', 'feb-24', 'mar-24', 'abr-24', 'may-24', 'jun-24'],
    'Beneficiarios': [1652, 1652, 1652, 1652, 1652, 1652, 1652],
    'Total ($)': [7266340.00, 7183630.00, 7124560.00, 12702770.00, 12200100.00, 12457970.00, 12457970.00]
}

data_infantiles = {
    'Mes': ['dic-23', 'ene-24', 'feb-24', 'mar-24', 'abr-24', 'may-24', 'jun-24'],
    'Beneficiarios': [13790, 13724, 13719, 15464, 15456, 15276, 16339],
    'Total ($)': [15281876.00, 14323640.00, 15956040.00, 30341340.00, 29410170.00, 29553190.00, 31241460.00]
}

data_reforzada = {
    'Mes': ['dic-23', 'ene-24', 'feb-24', 'mar-24', 'abr-24', 'may-24', 'jun-24'],
    'Beneficiarios': [120078, None, None, 120078, 120153, 119322, 126029],
    'Total ($)': [155733960.00, None, None, 523388000.00, 524946000.00, 535228839.00, 611632038.00]
}

data_provincia = {
    'Mes': ['dic-23', 'ene-24', 'feb-24', 'mar-24', 'abr-24', 'may-24', 'jun-24'],
    'Beneficiarios': [70452, None, None, 70452, 70418, 71178, 72955],
    'Total ($)': [79901948.69, None, None, 269586200.00, 270512000.00, 285265791.00, 312903854.00]
}

# Crear DataFrames
comedores_escolares = pd.DataFrame(data_comedores)
espacios_cuidado = pd.DataFrame(data_cuidado)
comunitarios_infantiles = pd.DataFrame(data_infantiles)
copa_leche_reforzada = pd.DataFrame(data_reforzada)
copa_leche_provincia = pd.DataFrame(data_provincia)

# Mostrar los DataFrames creados
print("Comedores Escolares:\n", comedores_escolares)
print("==================================================================")
print("Espacios de Cuidado:\n", espacios_cuidado)
print("==================================================================")
print("Comunitarios (Infantiles):\n", comunitarios_infantiles)
print("==================================================================")
print("Copa de Leche Reforzada:\n", copa_leche_reforzada)
print("==================================================================")
print("Copa de Leche Provincia:\n", copa_leche_provincia)
print("==================================================================")
# Out:
# Comedores Escolares:
#        Mes  Beneficiarios     Total ($)
# 0  dic-23         108277  3.248260e+08
# 1  ene-24          14422  1.297600e+08
# 2  feb-24          14372  8.696830e+07
# 3  mar-24         108005  1.079547e+09
# 4  abr-24         108074  1.085020e+09
# 5  may-24         109001  1.124986e+09
# 6  jun-24         111017  1.252675e+09
# ...
# Espacios de Cuidado:
#        Mes  Beneficiarios   Total ($)
# 0  dic-23           1652   7266340.0
# 1  ene-24           1652   7183630.0
# 2  feb-24           1652   7124560.0
# 3  mar-24           1652  12702770.0
# 4  abr-24           1652  12200100.0
# 5  may-24           1652  12457970.0
# 6  jun-24           1652  12457970.0
# ...
# Comunitarios (Infantiles):
#        Mes  Beneficiarios   Total ($)
# 0  dic-23          13790  15281876.0
# 1  ene-24          13724  14323640.0
# 2  feb-24          13719  15956040.0
# 3  mar-24          15464  30341340.0
# 4  abr-24          15456  29410170.0
# 5  may-24          15276  29553190.0
# ...

# %% [markdown]
# ### 2) Creo la función para generar gráficos:

# %%
import pandas as pd
import plotly.express as px

# Función para crear los gráficos:
def crear_graficos_programa(dataframe, titulo_programa):
    # Colores del gobierno
    color_beneficiarios = '#8FCB53'
    color_totales = '#6BAE39'

    # Crear el DataFrame
    dataframe['Total ($) Formatted'] = dataframe['Total ($)'].apply(lambda x: f"$ {x:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))

    # Gráfico de Beneficiarios mes a mes
    fig_beneficiarios = px.bar(dataframe, x='Mes', y='Beneficiarios',
                               title=f'Total (nº) de beneficiarios programa "{titulo_programa}" Dic-23/Jun-24',
                               color_discrete_sequence=[color_beneficiarios], text='Beneficiarios')
    fig_beneficiarios.update_layout(title_font_size=24, xaxis_title='Mes', yaxis_title='Beneficiarios', title_x=0.5)
    fig_beneficiarios.update_traces(texttemplate='%{text:,}', textposition='outside', textfont_size=14)
    fig_beneficiarios.update_yaxes(tickformat=",d")
    fig_beneficiarios.show()

    # Gráfico del Total ($) invertido mes a mes
    fig_totales = px.bar(dataframe, x='Mes', y='Total ($)',
                         title=f'Total ($) invertido en programa "{titulo_programa}" Dic-23/Jun-24',
                         color_discrete_sequence=[color_totales], text='Total ($) Formatted')
    fig_totales.update_layout(title_font_size=24, xaxis_title='Mes', yaxis_title='Total ($)', title_x=0.5)
    fig_totales.update_traces(texttemplate='%{text}', textposition='outside', textfont_size=14)
    fig_totales.update_yaxes(tickprefix="$", tickformat=",.0f")
    fig_totales.show()

# %% [markdown]
# ### 3) Ejecuto la función para cada programa:

# %%
crear_graficos_programa(comedores_escolares, "Comedores Escolares")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
crear_graficos_programa(espacios_cuidado, "Espacios de Cuidado")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
crear_graficos_programa(comunitarios_infantiles, "Comunitarios")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
crear_graficos_programa(copa_leche_reforzada, "Copa de Leche Reforzada")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
crear_graficos_programa(copa_leche_provincia, "Copa de Leche Provincia")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # TABLA: Cantidad Beneficiarios al inicio del ciclo lectivo (Mar24)

# %%
# DataFrame:
data_raciones = {
    'Programa': ['Comedores Escolares', 'Copa de Leche Reforzada', 'Copa de Leche Provincia'],
    'Raciones Diarias': [108005, 120078, 70452]
}

raciones_diarias = pd.DataFrame(data_raciones)

# Mostrar el DataFrame
print(raciones_diarias)
# Out:
#                   Programa  Raciones Diarias
# 0      Comedores Escolares            108005
# 1  Copa de Leche Reforzada            120078
# 2  Copa de Leche Provincia             70452

# %%
import plotly.express as px

# Crear el gráfico de barras
fig_raciones = px.bar(raciones_diarias, x='Programa', y='Raciones Diarias',
                      title='Raciones diarias al inicio del ciclo lectivo (Mar24)',
                      color='Programa', text='Raciones Diarias',
                      color_discrete_sequence=['#8FCB53', '#6BAE39', '#B5E575'])

# Añadir etiquetas personalizadas sobre las barras
fig_raciones.update_traces(texttemplate='%{text:,}', textposition='outside')

# Ajustar el diseño
fig_raciones.update_layout(title_font_size=24, xaxis_title='Programa', yaxis_title='Raciones Diarias', title_x=0.5)
fig_raciones.update_yaxes(tickformat=",d")

# Mostrar el gráfico
fig_raciones.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # TABLA: Costo unitario de Ración - Comedores: (Dic23-May24)

# %%
#DataFrame
data_costos = {
    'Programa': [
        'Comedores Escolares', 'Comedores Escolares', 'Comedores Escolares',
        'Espacios de Cuidado', 'Espacios de Cuidado',
        'Comunitarios (Infantiles)', 'Comunitarios',
        'Copa de Leche Reforzada', 'Copa de Leche Reforzada'
    ],
    'Comida': [
        'Almuerzo', 'Cena albergues', 'Refrigerio',
        'Asilos de ancianos', 'Espacios de cuidado',
        'Almuerzo', 'Merienda',
        'Desayuno', 'Merienda'
    ],
    'dic-23 a feb-24': [300, 230, 110, 120, 500, 90, 40, 130, 65],
    'mar-24 a may-24': [525, 405, 195, 210, 875, 160, 70, 230, 115]
}

costos_unitarios = pd.DataFrame(data_costos)

# Mostrar el DataFrame
print(costos_unitarios)
# Out:
#                     Programa               Comida  dic-23 a feb-24  \
# 0        Comedores Escolares             Almuerzo              300
# 1        Comedores Escolares       Cena albergues              230
# 2        Comedores Escolares           Refrigerio              110
# 3        Espacios de Cuidado   Asilos de ancianos              120
# 4        Espacios de Cuidado  Espacios de cuidado              500
# 5  Comunitarios (Infantiles)             Almuerzo               90
# 6               Comunitarios             Merienda               40
# 7    Copa de Leche Reforzada             Desayuno              130
# 8    Copa de Leche Reforzada             Merienda               65
#
#    mar-24 a may-24
# 0              525
# 1              405
# 2              195
# 3              210
# 4              875
# 5              160
# 6               70
# 7              230
# 8              115

# %%
# Función para crear los gráficos de barras comparativos por programa
def crear_grafico_comparativo(dataframe, programa):
    df_programa = dataframe[dataframe['Programa'] == programa]
    df_programa_melted = df_programa.melt(id_vars=['Comida'], value_vars=['dic-23 a feb-24', 'mar-24 a may-24'],
                                          var_name='Periodo', value_name='Costo')

    fig = px.bar(df_programa_melted, x='Comida', y='Costo', color='Periodo', barmode='group',
                 title=f'Aumento de Costos de Ración en Marzo 2024 - {programa}',
                 labels={'Comida': 'Tipo de Comida', 'Costo': 'Costo ($)', 'Periodo': 'Período'},
                 color_discrete_sequence=['#8FCB53', '#6BAE39'])

    fig.update_layout(title_font_size=24, xaxis_title='Comida', yaxis_title='Costo ($)', title_x=0.5)
    fig.show()

# Crear gráficos para cada programa
crear_grafico_comparativo(costos_unitarios, 'Comedores Escolares')
crear_grafico_comparativo(costos_unitarios, 'Espacios de Cuidado')
crear_grafico_comparativo(costos_unitarios, 'Comunitarios')
crear_grafico_comparativo(costos_unitarios, 'Copa de Leche Reforzada')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
